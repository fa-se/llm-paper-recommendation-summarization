# %%
import os
import sys

project_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_path not in sys.path:
    sys.path.append(project_path)

from dotenv import load_dotenv

load_dotenv(os.path.join(project_path, '.env'), override=True)
# Out:
# True

# %%
import pyalex
from llmrankers.setwise import OpenAiSetwiseLlmRanker
from llmrankers.rankers import SearchResult
from itertools import chain


# monkey patch pyalex.Work to implement __hash__ (using id)
def custom_hash(self):
    return id(self)


pyalex.Work.__hash__ = custom_hash

# %%
from cli.main import Services
from core.dataclasses.data_classes import Work, ScoredWork

services = Services()
publication_service = services.publication_service
user_service = services.user_service
publication_repository = publication_service.publication_repository
user_repository = user_service.user_repository

# %%
# db setup
from db.utils import recreate_tables
def clean_tables():
    # truncate publication and user table (cascading)
    publication_repository.truncate() 
    user_repository.truncate()

# %%
from core.sqlalchemy_models.openalex.topic import Topic
def create_profile(user_name: str, publication: pyalex.Work) ->list[str]:
    topic_associations, _ = user_service.set_area_of_interest(
        user_name, publication["abstract"], align_description=False, n_topics=10
    )
    topics = [association.topic.name for association in topic_associations]
    return topics

# %%
import math


def get_random_publications_openalex(n: int) -> list[pyalex.Work]:
    pager = (pyalex.Works().sample(n, seed=42)
             .filter(has_abstract=True)
             .filter(has_references=True)
             .paginate(method="page", per_page=100))
    publications = []
    for page in pager:
        publications.extend(page)
    return publications


def filter_ineligible_publications(publications: list[pyalex.Work], max: int) -> list[pyalex.Work]:
    filtered_publications = []
    for publication in publications:
        if len(publication["referenced_works"]) >= 20:
            filtered_publications.append(publication)
            if len(filtered_publications) >= max:
                break

    return filtered_publications


def get_referenced_publications(publication: pyalex.Work, require_abstract=False) -> set[pyalex.Work]:
    referenced_publications = set()
    reference_ids = set(publication["referenced_works"])
    reference_ids = ["W" + reference.split("W")[-1] for reference in
                     reference_ids]  # use shortened ids because query gets too long otherwise 
    for i in range(0, len(reference_ids), 100):
        query = (
            pyalex.Works()
            .filter(openalex="|".join(reference_ids[i: i + 100]))
        )        
        if require_abstract:
            query = query.filter(has_abstract=True)
            
        for pyalex_work in chain(*query.paginate(per_page=100, n_max=100)):
            if pyalex_work["id"] != "https://openalex.org/W4285719527":  # deleted works are represented by this dummy entity
                referenced_publications.add(pyalex_work)
                
    return referenced_publications

def insert_publications(publications: list[pyalex.Work]):
    from datetime import datetime
    from core.llm_interfaces import OpenAIInterface
    # first, convert to our own dataclass 
    publications_converted = [Work(publication) for publication in publications]
    
    openai_interface = OpenAIInterface(print_usage_info=False)
    abstracts = [work.abstract for work in publications_converted]
    abstract_embeddings = openai_interface.create_embedding_batch(abstracts)

    # make sure all referenced works are in the database
    for i, work in enumerate(publications_converted):
        publication = publication_repository.get_by_openalex_id(work.id)
        if not publication:
             publication_repository.create(
                openalex_id=work.id,
                title=work.title,
                authors=work.authors,
                abstract=work.abstract,
                published=work.publication_date,
                accessed=datetime.now(),
                embedding=abstract_embeddings[i],
            )
    print("Rebuilding BM25 index...")
    publication_repository.rebuild_bm25()
    print("Rebuilt BM25 index.")
    
def check_all_publications_in_db(publications: list[pyalex.Work]) -> list[str]:
    """
    Checks whether all cited works are actually in the database, and returns a list of those that are not.
    """
    missed_publications = []
    for publication in publications:
        result = publication_repository.get_by_openalex_id(int(publication["id"].split("W")[-1]))
        if not publication:
            missed_publications.append(result)
    return missed_publications

def convert_to_pyalex_works(works: list[Work]) -> list[pyalex.Work]:
    pyalex_works = []
    openalex_ids = [f"W{work.id}" for work in works]
    
    for i in range(0, len(openalex_ids), 100):
        query = pyalex.Works().filter(openalex="|".join(openalex_ids[i : i + 100]))
        for pyalex_work in chain(*query.paginate(per_page=100, n_max=100)):
            pyalex_works.append(pyalex_work)
        
    return pyalex_works

def get_retrieval_results(publication: pyalex.Work, n: int = 100) -> list[Work]:
    from core.services.publication_service import SearchType
    start_date = datetime(1900, 1, 1)
    query = publication["abstract"]
    results_hybrid = publication_service.get_relevant_works_for_query(query, n + 10, start_date, SearchType.HYBRID) # some buffer to account for possible duplicates
    # remove works with score < 0.95 (likely the query document itself)
    results_hybrid = [scored_work.work for scored_work in results_hybrid if scored_work.score < 0.95]

    return convert_to_pyalex_works(results_hybrid[:n])

def rerank(query_work: pyalex.Work, retrieval_results: list[pyalex.Work]) -> tuple[list[Work], float]:
    reranker = OpenAiSetwiseLlmRanker(model_name_or_path="gpt-4o-mini-2024-07-18", api_key=os.getenv("OPENAI_API_KEY"), method="heapsort", num_child=2, k=10)
    price_per_input_token = 0.15 / 1e6
    price_per_output_token = 0.6 / 1e6
    total_usage = {"total_prompt_tokens": 0, "total_completion_tokens": 0}
    
    docs = [SearchResult(docid=result["id"], text=result["abstract"], score=None) for result in retrieval_results]
    reranked_docs, usage = reranker.rerank(query_work["abstract"], docs)
    reranked_works = []
    for doc in reranked_docs:
            reranked_works.extend([work for work in retrieval_results if work["id"] == doc.docid])        
    
    total_usage["total_prompt_tokens"] += usage["total_prompt_tokens"]
    total_usage["total_completion_tokens"] += usage["total_completion_tokens"]
    cost = total_usage["total_prompt_tokens"] * price_per_input_token + total_usage["total_completion_tokens"] * price_per_output_token
    print(f"Reranking cost: {cost}")
    
    return reranked_works, cost

from dataclasses import dataclass
@dataclass
class ResultStats:
        run: int
        type: str
        query_work: str
        result_work: str
        result_rank: int
        common_references: int
        max_common_references: int
        is_reference_of_citing_work: bool
        num_query_work_references_in_corpus: int
        
        
        

def calculate_stats(query_work: pyalex.Work, query_work_references_in_corpus: list[pyalex.Work], retrieval_results: list[pyalex.Work], run: int, type: str) -> list[ResultStats]:
    stats = []
    
    query_work_reference_ids = set(query_work["referenced_works"])
    num_query_work_references_in_corpus = len(query_work_references_in_corpus) # relevant for calculating (retrieved_references / max_retrieved_references)
    
    for i, retrieved_work in enumerate(retrieval_results):
        result_reference_ids = set(retrieved_work["referenced_works"])
        common_references = query_work_reference_ids.intersection(result_reference_ids)
        max_common_references = min(len(query_work_reference_ids), len(result_reference_ids))
        is_reference_of_citing_work = retrieved_work["id"] in query_work_reference_ids
        
        stats.append(
            ResultStats(
                run=run,
                type=type,
                query_work=query_work["id"],
                result_work = retrieved_work["id"],
                result_rank = i + 1, # 1-indexed
                common_references= len(common_references),
                max_common_references=max_common_references,
                is_reference_of_citing_work=is_reference_of_citing_work,
                num_query_work_references_in_corpus = num_query_work_references_in_corpus   
        ))   
    
    return stats

# %%
from datetime import datetime
import pandas as pd

# %%
from datetime import datetime
import pandas as pd

timestamp = datetime.now().isoformat()

n = 100
limit_initial_retrieval = 2000  
start_date = datetime(2020, 1, 1)
random_publications = get_random_publications_openalex(n * 5)
filtered_publications = filter_ineligible_publications(random_publications, max=n)

reranking_cost = 0.0
stats = []
for i, query_work in enumerate(filtered_publications):
    print(f"Run: {i} --- Title: {query_work['title']}, id: {query_work['id']}")
    # clean db and create user + profile
    clean_tables()
    user_service.create_user("eval_user", "Eval User", "-")
    topics = create_profile("eval_user", query_work)
    print(f"Top 3 topics: {topics[:3]}")
    publications_retrieved_for_topics = publication_service.initialize_for_user("eval_user", start_date=start_date, limit=limit_initial_retrieval)
    print(f"Retrieved and inserted {len(publications_retrieved_for_topics)} publications.")    
    referenced_works = get_referenced_publications(query_work, require_abstract=True)
    insert_publications(referenced_works)
    print(f"Inserted {len(referenced_works)} referenced works.")
    # sanity check: are all referenced works in the database?
    print(f"Found all referenced works in the database? {len(check_all_publications_in_db(referenced_works)) == 0}")
    retrieval_results = get_retrieval_results(query_work, 100)
    print(f"Top 5 results: {"".join(f'\n\t{result["title"]}' for result in retrieval_results[:5])}")
    print(f"Reranking...")
    reranked_results, cost = rerank(query_work, retrieval_results)
    reranking_cost += cost
    print(f"Reranked results: {"".join(f'\n\t{result["title"]}' for result in reranked_results[:5])}")
    print(f"Accumulated reranking cost: {reranking_cost}")
    retrieval_stats = calculate_stats(query_work=query_work,query_work_references_in_corpus=referenced_works, retrieval_results=retrieval_results, run=i, type="retrieval")
    reranking_stats = calculate_stats(query_work=query_work,query_work_references_in_corpus=referenced_works, retrieval_results=reranked_results, run=i, type="reranking")
    
    stats.extend(retrieval_stats)
    stats.extend(reranking_stats)
    
    df = pd.DataFrame(stats)
    # save to timestamped pickle file
    df.to_pickle(f"eval_common_references_{timestamp}.pkl")
    
    print("-" * 80)
# Out:
# Run: 0 --- Title: Original Articles Immunoreactivity of Stat5 Phosphorylated on Tyrosine as a Cell-Based Measure of Bcr/Abl Kinase Activity, id: https://openalex.org/W316998542
# Model: text-embedding-3-large, Tokens: 120, Cost: $0.00, Accumulated cost: $0.00
# Top 3 topics: ['Role of STAT3 in Cancer Inflammation and Immunity', 'Transforming Growth Factor Beta Signaling Pathway', 'Calcineurin-NFAT Signaling in Transcriptional Regulation']
# Model: text-embedding-3-large, Tokens: 710638, Cost: $0.09, Accumulated cost: $0.09
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 34 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 120, Cost: $0.00, Accumulated cost: $0.09
# Top 5 results:
# 	The JAK/STAT signaling pathway: from bench to clinic
# 	The role of shared receptor motifs and common stat proteins in the generation of cytokine pleiotropy and redundancy by IL-2, IL-4, IL-7, IL-13, and IL-15
# 	The role of JAK/STAT signaling pathway and its inhibitors in diseases
# 	Tyrosyl phosphorylation and DNA binding activity of signal transducers and activators of transcription (STAT) proteins in hematopoietic cell lines transformed by Bcr/Abl.
# 	P210 and P190 Induce the Tyrosine Phosphorylation and DNA Binding Activity of Multiple Specific STAT Family Members
# Reranking...
# Total compare: 136, Total prompt tokens: 136740, Total completion tokens: 408
# Reranking cost: 0.020755799999999998
# Reranked results:
# 	Signal Transducer and Activator of Transcription (STAT)5 Activation by BCR/ABL Is Dependent on Intact Src Homology (SH)3 and SH2 Domains of BCR/ABL and Is Required for Leukemogenesis
# 	Tyrosyl phosphorylation and DNA binding activity of signal transducers and activators of transcription (STAT) proteins in hematopoietic cell lines transformed by Bcr/Abl.
# 	P210 and P190 Induce the Tyrosine Phosphorylation and DNA Binding Activity of Multiple Specific STAT Family Members
# 	STAT5-Dependent CyclinD1 and Bcl-xL Expression in Bcr-Abl-Transformed Cells
# 	Constitutive activation of JAKs and STATs in BCR-Abl-expressing cell lines and peripheral blood cells derived from leukemic patients.
# Accumulated reranking cost: 0.020755799999999998
# --------------------------------------------------------------------------------
# Run: 1 --- Title: Social functioning of elderly persons with malignant diseases, id: https://openalex.org/W2140916303
# Model: text-embedding-3-large, Tokens: 390, Cost: $0.00, Accumulated cost: $0.09
# Top 3 topics: ['Cancer Survivorship and Quality of Life', 'Health-Related Quality of Life in Aging Population', 'Impact of Social Factors on Health Outcomes']
# Model: text-embedding-3-large, Tokens: 1042573, Cost: $0.14, Accumulated cost: $0.23
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 18 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 390, Cost: $0.00, Accumulated cost: $0.23
# Top 5 results:
# 	COVID-19 mortality in patients with cancer on chemotherapy or other anticancer treatments: a prospective cohort study
# 	COVID-19 in patients with thoracic malignancies (TERAVOLT): first results of an international, registry-based, cohort study
# 	Older people and COVID‐19: Isolation, risk and ageism
# 	Clinical characteristics and risk factors associated with COVID-19 disease severity in patients with cancer in Wuhan, China: a multicentre, retrospective, cohort study
# 	Clinical characteristics and risk factors associated with COVID-19 severity in patients with haematological malignancies in Italy: a retrospective, multicentre, cohort study
# Reranking...
# Unexpected output: None
# Total compare: 146, Total prompt tokens: 422293, Total completion tokens: 436
# Reranking cost: 0.06360555
# Reranked results:
# 	Social support for older adults with cancer: Young International Society of Geriatric Oncology review paper
# 	Quality of life in older people with cancer - a gender perspective
# 	Disability, psychological distress and quality of life in relation to cancer diagnosis and cancer type: population-based Australian study of 22,505 cancer survivors and 244,000 people without cancer
# 	Quality of Life of Cancer Patients Treated with Chemotherapy
# 	Social Support, Isolation, Loneliness, and Health Among Older Adults in the PRISM Randomized Controlled Trial
# Accumulated reranking cost: 0.08436135
# --------------------------------------------------------------------------------
# Run: 2 --- Title: Clinical Outcomes and Refractive Error Characteristics in Patients with Congenital Blepharoptosis after Ptosis Repair Surgery, id: https://openalex.org/W2998359868
# Model: text-embedding-3-large, Tokens: 399, Cost: $0.00, Accumulated cost: $0.23
# Top 3 topics: ['Cataract Surgery Techniques and Complications', 'Comparison of Dacryocystorhinostomy Techniques and Outcomes', 'Vitreoretinal Surgery Techniques']
# Model: text-embedding-3-large, Tokens: 847994, Cost: $0.11, Accumulated cost: $0.34
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 25 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 399, Cost: $0.00, Accumulated cost: $0.34
# Top 5 results:
# 	Refractive Errors Associated With Hemangiomas of the Eyelids and Orbit in Infancy
# 	Treatment of Congenital Ptosis with Frontalis Suspension
# 	Intraocular Lens Implantation in the Absence of Zonular Support: An Outcomes and Safety Update
# 	Primary Retinal Detachment Outcomes Study Report Number 2
# 	Trans-scleral plugs fixated IOL: a new paradigm for sutureless scleral fixation
# Reranking...
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Total compare: 143, Total prompt tokens: 258158, Total completion tokens: 419
# Reranking cost: 0.0389751
# Reranked results:
# 	Factors Associated With Surgical Outcomes in Congenital Ptosis: A 10-Year Study of 319 Cases
# 	Change in refractive error after unilateral levator resection for congenital ptosis
# 	Astigmatic change following congenital ptosis surgery.
# 	Changes in Astigmatism After Surgery for Congenital Ptosis
# 	Maximal levator resection in unilateral congenital ptosis with poor levator function
# Accumulated reranking cost: 0.12333645
# --------------------------------------------------------------------------------
# Run: 3 --- Title: Classification of robotic arm movement using SVM and Na&amp;#x00EF;ve Bayes classifiers, id: https://openalex.org/W1965335952
# Model: text-embedding-3-large, Tokens: 196, Cost: $0.00, Accumulated cost: $0.34
# Top 3 topics: ['Robotic Grasping and Learning from Demonstration', 'Kinematic and Dynamic Analysis of Robot Manipulators', 'Computational Principles of Motor Control and Learning']
# Model: text-embedding-3-large, Tokens: 506123, Cost: $0.07, Accumulated cost: $0.40
# Retrieved and inserted 1999 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 21 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 196, Cost: $0.00, Accumulated cost: $0.40
# Top 5 results:
# 	A Survey on Learning-Based Robotic Grasping
# 	Review of machine learning methods in soft robotics
# 	Machine Learning for Soft Robotic Sensing and Control
# 	Toward Teaching by Demonstration for Robot-Assisted Minimally Invasive Surgery
# 	Distributed Proprioception of 3D Configuration in Soft, Sensorized Robots via Deep Learning
# Reranking...
# Total compare: 139, Total prompt tokens: 136144, Total completion tokens: 417
# Reranking cost: 0.020671799999999997
# Reranked results:
# 	An analytical and a Deep Learning model for solving the inverse kinematic problem of an industrial parallel robot
# 	Learning inverse kinematics and dynamics of a robotic manipulator using generative adversarial networks
# 	Analysis of the Inverse Kinematics and Trajectory Planning Applied in a Classic Collaborative Industrial Robotic Manipulator
# 	Inverse kinematics in robotics using neural networks
# 	Optimal Feedback Control for anthropomorphic manipulators
# Accumulated reranking cost: 0.14400825
# --------------------------------------------------------------------------------
# Run: 4 --- Title: ASSESSMENT OF BIODENTINE PULPOTOMY AS AN ALTERNATIVE TO CONVENTIONAL ROOT CANAL TREATMENT FOR PERMANENT TEETH IN CHILDREN-AN IN VIVO STUDY, id: https://openalex.org/W4386403491
# Model: text-embedding-3-large, Tokens: 454, Cost: $0.00, Accumulated cost: $0.40
# Top 3 topics: ['Endodontic Research and Practice', 'Epidemiology and Management of Traumatic Dental Injuries', 'Advancements in Dental Research and Treatment']
# Model: text-embedding-3-large, Tokens: 742897, Cost: $0.10, Accumulated cost: $0.50
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 37 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 454, Cost: $0.00, Accumulated cost: $0.50
# Top 5 results:
# 	Response of Human Dental Pulp Capped with Biodentine and Mineral Trioxide Aggregate
# 	Biodentine Induces Immortalized Murine Pulp Cell Differentiation into Odontoblast-like Cells and Stimulates Biomineralization
# 	A prospective cohort study of endodontic treatments of 1,369 root canals: results after 5 years
# 	Clinical evaluation of the performance and safety of a new dentine substitute, Biodentine, in the restoration of posterior teeth — a prospective study
# 	MTA versus Biodentine: Review of Literature with a Comparative Analysis
# Reranking...
# Total compare: 143, Total prompt tokens: 228093, Total completion tokens: 429
# Reranking cost: 0.03447135
# Reranked results:
# 	Outcome of full pulpotomy using Biodentine in adult patients with symptoms indicative of irreversible pulpitis
# 	Factors that influence the outcome of pulpotomy in permanent teeth
# 	Outcome of full pulpotomy in mature permanent molars using 3 calcium silicate‐based materials: A parallel, double blind, randomized controlled trial
# 	Conservative Management of Mature Permanent Teeth with Carious Pulp Exposure
# 	A comparison of MTA and Biodentine as medicaments for pulpotomy in traumatized anterior immature permanent teeth: A randomized clinical trial
# Accumulated reranking cost: 0.17847960000000002
# --------------------------------------------------------------------------------
# Run: 5 --- Title: Application of the molecular mechanics method to simulation of buckling of single-walled carbon nanotubes, id: https://openalex.org/W2071369435
# Model: text-embedding-3-large, Tokens: 348, Cost: $0.00, Accumulated cost: $0.50
# Top 3 topics: ['Mechanics and Fracture of Nanomaterials and Composites', 'Nanomaterials and Mechanical Properties', 'Nonlocal Continuum Mechanics in Nanoscale Materials']
# Model: text-embedding-3-large, Tokens: 492423, Cost: $0.06, Accumulated cost: $0.56
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 25 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 348, Cost: $0.00, Accumulated cost: $0.57
# Top 5 results:
# 	Molecular mechanics. The MM3 force field for hydrocarbons. 1
# 	Carbon nanotubes, buckyballs, ropes, and a universal graphitic potential
# 	Atomistic simulations of nanotube fracture
# 	Equivalent-continuum modeling of nano-structured materials
# 	Finite crystal elasticity of carbon nanotubes based on the exponential Cauchy-Born rule
# Reranking...
# Total compare: 138, Total prompt tokens: 169354, Total completion tokens: 414
# Reranking cost: 0.025651499999999997
# Reranked results:
# 	Using stability analysis of discrete elastic systems to study the buckling of nanostructures
# 	Recent Studies on Buckling of Carbon Nanotubes
# 	Buckling Analysis of Carbon Nanotubes – a molecular mechanics approach using the finite element framework
# 	Buckling of Carbon Nanotubes: A State of the Art Review
# 	Torsional behavior of chiral single-walled carbon nanotubes is loading direction dependent
# Accumulated reranking cost: 0.2041311
# --------------------------------------------------------------------------------
# Run: 6 --- Title: Persons or aliens? : making normative sense of non-citizens' legal standing in the U.S. and Germany, id: https://openalex.org/W1795762583
# Model: text-embedding-3-large, Tokens: 181, Cost: $0.00, Accumulated cost: $0.57
# Top 3 topics: ['Politics and Social Implications of Immigration', 'Theoretical Perspectives on Global Justice', 'Transnational Diasporas and Migration Studies']
# Model: text-embedding-3-large, Tokens: 505296, Cost: $0.07, Accumulated cost: $0.63
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 64 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 181, Cost: $0.00, Accumulated cost: $0.63
# Top 5 results:
# 	Between Facts and Norms
# 	Citizenship and nationhood in France and Germany
# 	Justice Beyond Borders
# 	Citizenship: The Civic Ideal in World History Politics and Education
# 	Philosophies of Exclusion: Liberal Political Theory and Immigration
# Reranking...
# Total compare: 146, Total prompt tokens: 145869, Total completion tokens: 438
# Reranking cost: 0.02214315
# Reranked results:
# 	Strangers to the Constitution
# 	Without Justice For All: The Constitutional Rights of Aliens
# 	Pursuing Citizenship in the Enforcement Era
# 	Citizenship, domicile and deportability: who should be exempt from the state’s power to expel?
# 	Philosophies of Exclusion
# Accumulated reranking cost: 0.22627425
# --------------------------------------------------------------------------------
# Run: 7 --- Title: Hydrotropic pretreatment on distillery stillage for efficient cellulosic ethanol production, id: https://openalex.org/W2994739503
# Model: text-embedding-3-large, Tokens: 223, Cost: $0.00, Accumulated cost: $0.63
# Top 3 topics: ['Technologies for Biofuel Production from Biomass', 'Lignin Degradation by Enzymes in Bioremediation', 'Supercritical Water Gasification for Hydrogen Production']
# Model: text-embedding-3-large, Tokens: 544567, Cost: $0.07, Accumulated cost: $0.70
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 35 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 223, Cost: $0.00, Accumulated cost: $0.70
# Top 5 results:
# 	Lignocellulosic biomass to bioethanol, a comprehensive review with a focus on pretreatment
# 	Stillage characterization and anaerobic treatment of ethanol stillage from conventional and cellulosic feedstocks
# 	Pretreatment of lignocellulosic biomass: A review on recent advances
# 	Different pretreatment technologies of lignocellulosic biomass for bioethanol production: An overview
# 	Lignocellulosic biomass: Acid and alkaline pretreatments and their effects on biomass recalcitrance – Conventional processing and recent advances
# Reranking...
# Total compare: 121, Total prompt tokens: 128784, Total completion tokens: 363
# Reranking cost: 0.0195354
# Reranked results:
# 	Evaluation of hydrotropic pretreatment on lignocellulosic biomass
# 	Topochemistry of alkaline, alkaline-peroxide and hydrotropic pretreatments of common reed to enhance enzymatic hydrolysis efficiency
# 	Topochemical pretreatment of wood biomass to enhance enzymatic hydrolysis of polysaccharides to sugars
# 	Microwave-assisted dilute acid pretreatment in bioethanol production from wheat and rye stillages
# 	Green hydrotropic extraction technology for delignification of sugarcane bagasse by using alkybenzene sulfonates as hydrotropes
# Accumulated reranking cost: 0.24580965000000002
# --------------------------------------------------------------------------------
# Run: 8 --- Title: M6A-related bioinformatics analysis reveals that HNRNPC facilitates progression of OSCC via EMT, id: https://openalex.org/W3034648201
# Model: text-embedding-3-large, Tokens: 324, Cost: $0.00, Accumulated cost: $0.70
# Top 3 topics: ['RNA Methylation and Modification in Gene Expression', 'Small Cell Lung Cancer', 'Role of Long Noncoding RNAs in Cancer and Development']
# Model: text-embedding-3-large, Tokens: 828142, Cost: $0.11, Accumulated cost: $0.81
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 28 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 324, Cost: $0.00, Accumulated cost: $0.81
# Top 5 results:
# 	RNA N6‐methyladenosine methyltransferase‐like 3 promotes liver cancer progression through YTHDF2‐dependent posttranscriptional silencing of SOCS2
# 	m6A Modification in Coding and Non-coding RNAs: Roles and Therapeutic Implications in Cancer
# 	The role of m6A RNA methylation in human cancer
# 	m6A regulator-mediated methylation modification patterns and tumor microenvironment infiltration characterization in gastric cancer
# 	m6A mRNA methylation regulates AKT activity to promote the proliferation and tumorigenicity of endometrial cancer
# Reranking...
# Total compare: 134, Total prompt tokens: 194295, Total completion tokens: 402
# Reranking cost: 0.02938545
# Reranked results:
# 	METTL3 Facilitates Oral Squamous Cell Carcinoma Tumorigenesis by Enhancing c-Myc Stability via YTHDF1-Mediated m6A Modification
# 	METTL3 Promotes Tumorigenesis and Metastasis through BMI1 m6A Methylation in Oral Squamous Cell Carcinoma
# 	RNA N6-methyladenosine reader IGF2BP2 promotes lymphatic metastasis and epithelial-mesenchymal transition of head and neck squamous carcinoma cells via stabilizing slug mRNA in an m6A-dependent manner
# 	The m6A demethylase ALKBH5 promotes tumor progression by inhibiting RIG-I expression and interferon alpha production through the IKKε/TBK1/IRF3 pathway in head and neck squamous cell carcinoma
# 	Role of m6A writers, erasers and readers in cancer
# Accumulated reranking cost: 0.2751951
# --------------------------------------------------------------------------------
# Run: 9 --- Title: A Sketch-Based Approach for Interactive Organization of Video Clips, id: https://openalex.org/W1997557743
# Model: text-embedding-3-large, Tokens: 301, Cost: $0.00, Accumulated cost: $0.81
# Top 3 topics: ['Automatic Video Summarization and Analysis', 'Understanding Social Television Viewing and Interaction', 'Motion Synthesis and Control Techniques']
# Model: text-embedding-3-large, Tokens: 501450, Cost: $0.07, Accumulated cost: $0.87
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 24 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 301, Cost: $0.00, Accumulated cost: $0.87
# Top 5 results:
# 	Learning Transferable Visual Models From Natural Language Supervision
# 	Video abstraction
# 	Less is More: CLIPBERT for Video-and-Language Learning via Sparse Sampling
# 	Beyond Distance Measurement: Constructing Neighborhood Similarity for Video Annotation
# 	Frozen in Time: A Joint Video and Image Encoder for End-to-End Retrieval
# Reranking...
# Total compare: 126, Total prompt tokens: 144975, Total completion tokens: 378
# Reranking cost: 0.021973049999999997
# Reranked results:
# 	A hierarchical organization scheme for video data
# 	DEMAIS
# 	Video abstraction
# 	InsightVideo: toward hierarchical video content organization for efficient browsing, summarization and retrieval
# 	Video indexing based on mosaic representations
# Accumulated reranking cost: 0.29716815
# --------------------------------------------------------------------------------
# Run: 10 --- Title: Pyrimido[4,5-g]quinazoline-4,9-dione as a new building block for constructing polymer semiconductors with high sensitivity to acids and hole transport performance in organic thin film transistors, id: https://openalex.org/W1883803253
# Model: text-embedding-3-large, Tokens: 52, Cost: $0.00, Accumulated cost: $0.87
# Top 3 topics: ['Polyimide Materials Research', 'Chemistry of Pyrrolobenzodiazepines', 'Polyhedral Oligomeric Silsesquioxanes']
# Model: text-embedding-3-large, Tokens: 573328, Cost: $0.07, Accumulated cost: $0.95
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 43 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 52, Cost: $0.00, Accumulated cost: $0.95
# Top 5 results:
# 	Fluorescent Porous Polymer Films as TNT Chemosensors: Electronic and Structural Effects
# 	High mobility diketopyrrolopyrrole (DPP)-based organic semiconductor materials for organic thin film transistors and photovoltaics
# 	A High Mobility P‐Type DPP‐Thieno[3,2‐<i>b</i>]thiophene Copolymer for Organic Thin‐Film Transistors
# 	High-Performance Air-Stable Organic Field-Effect Transistors: Isoindigo-Based Conjugated Polymers
# 	“Conformation Locked” Strong Electron-Deficient Poly(<i>p</i>-Phenylene Vinylene) Derivatives for Ambient-Stable n-Type Field-Effect Transistors: Synthesis, Properties, and Effects of Fluorine Substitution Position
# Reranking...
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None of the passages are directly relevant to the query about polymers based on pyrimido[4,5-g]quinazoline-4,9-dione (PQ) building block.
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Total compare: 115, Total prompt tokens: 102016, Total completion tokens: 1335
# Reranking cost: 0.0161034
# Reranked results:
# 	New synthetic route to pyrimido[4,5-g]quinazoline-4,9-diones
# 	Spectroscopic changes of π-conjugated polyquinoxaline and a copolymer of heptylbenzimidazole and thiophene caused by protonation with trifluoroacetic acid
# 	A New Polymer Donor Enables Binary All‐Polymer Organic Photovoltaic Cells with 18% Efficiency and Excellent Mechanical Robustness
# 	Preparation and properties of π-conjugated poly(benzimidazole-4,7-diyl)s
# 	Preparation of π-conjugated polymers consisting of 2-decylbenzimidazole and thiophene units and chemical properties of the polymers
# Accumulated reranking cost: 0.31327155
# --------------------------------------------------------------------------------
# Run: 11 --- Title: New Structure, Traditional Essence: Patterns of Helping Non-Coresident Parents by Own and Sibling(s)’ Gender in China, id: https://openalex.org/W3162039760
# Model: text-embedding-3-large, Tokens: 186, Cost: $0.00, Accumulated cost: $0.95
# Top 3 topics: ['Intergenerational Family Relationships and Support', 'Gender Imbalance in East and South Asia', 'Family Structure and Fertility Patterns']
# Model: text-embedding-3-large, Tokens: 520030, Cost: $0.07, Accumulated cost: $1.02
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 39 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 186, Cost: $0.00, Accumulated cost: $1.02
# Top 5 results:
# 	The Structure of Intergenerational Exchanges in American Families
# 	Intergenerational Social Support and the Psychological Well-Being of Older Parents in China
# 	Gender And Elder Care In China
# 	Sexual Stratification: The Other Side of "Growth with Equity" in East Asia
# 	Family size and support of older adults in urban and rural China: Current effects and future implications
# Reranking...
# Total compare: 134, Total prompt tokens: 131914, Total completion tokens: 402
# Reranking cost: 0.0200283
# Reranked results:
# 	The impact of son or daughter care on Chinese older adults' mental health
# 	Trajectories and Determinants of Elder Care in Rural China During an 8-Year Period
# 	Do Sons or Daughters Give More Money to Parents in Urban China?
# 	Intergenerational relations in urban China: Proximity, contact, and help to parents
# 	Gender And Elder Care In China
# Accumulated reranking cost: 0.33329985
# --------------------------------------------------------------------------------
# Run: 12 --- Title: Asymmetric Response of Volatility: Evidence from Stochastic Volatility Models and Realized Volatility, id: https://openalex.org/W2091715562
# Model: text-embedding-3-large, Tokens: 158, Cost: $0.00, Accumulated cost: $1.02
# Top 3 topics: ['Modeling and Forecasting Financial Volatility', 'Theory and Applications of Option Pricing Models', 'Skew Distributions and Applications in Statistics']
# Model: text-embedding-3-large, Tokens: 389929, Cost: $0.05, Accumulated cost: $1.07
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 45 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 158, Cost: $0.00, Accumulated cost: $1.07
# Top 5 results:
# 	Conditional Heteroskedasticity in Asset Returns: A New Approach
# 	On the Relation between the Expected Value and the Volatility of the Nominal Excess Return on Stocks
# 	Expected stock returns and volatility
# 	Measuring and Testing the Impact of News on Volatility
# 	The Pricing of Options on Assets with Stochastic Volatilities
# Reranking...
# Total compare: 126, Total prompt tokens: 98284, Total completion tokens: 378
# Reranking cost: 0.014969399999999999
# Reranked results:
# 	Estimating Semiparametric ARCH(oo) Models by Kernel Smoothing Methods1
# 	Estimating semiparametric ARCH (∞) models by kernel smoothing methods
# 	Measuring and Testing the Impact of News on Volatility
# 	A generalized partially linear model of asymmetric volatility
# 	Asymmetric volatility structure of equity returns: Evidence from an emerging market
# Accumulated reranking cost: 0.34826925000000003
# --------------------------------------------------------------------------------
# Run: 13 --- Title: Protective effect of hydroxychloroquine on renal damage in patients with lupus nephritis: LXV, data from a multiethnic US cohort, id: https://openalex.org/W2015040567
# Model: text-embedding-3-large, Tokens: 527, Cost: $0.00, Accumulated cost: $1.07
# Top 3 topics: ['Ocular Toxicity and Retinal Disorders from Medications', 'Systemic Lupus Erythematosus and Antiphospholipid Syndrome', 'Mechanisms and Renoprotective Strategies for Cisplatin Nephrotoxicity']
# Model: text-embedding-3-large, Tokens: 939943, Cost: $0.12, Accumulated cost: $1.19
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 50 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 527, Cost: $0.00, Accumulated cost: $1.19
# Top 5 results:
# 	Mechanisms of action of hydroxychloroquine and chloroquine: implications for rheumatology
# 	A Randomized Study of the Effect of Withdrawing Hydroxychloroquine Sulfate in Systemic Lupus Erythematosus
# 	2019 Update of the Joint European League Against Rheumatism and European Renal Association–European Dialysis and Transplant Association (EULAR/ERA–EDTA) recommendations for the management of lupus nephritis
# 	Effect of hydroxychloroquine on the survival of patients with systemic lupus erythematosus: data from LUMINA, a multiethnic US cohort (LUMINA L)
# 	Predicting renal outcomes in severe lupus nephritis: Contributions of clinical and histologic data
# Reranking...
# Total compare: 131, Total prompt tokens: 373068, Total completion tokens: 393
# Reranking cost: 0.056195999999999996
# Reranked results:
# 	Previous antimalarial therapy in patients diagnosed with lupus nephritis: Influence on outcomes and survival
# 	Effect of hydroxychloroquine on the survival of patients with systemic lupus erythematosus: data from LUMINA, a multiethnic US cohort (LUMINA L)
# 	Hydroxychloroquine in systemic lupus erythematosus: overview of current knowledge
# 	A Long-Term Study of Hydroxychloroquine Withdrawal on Exacerbations in Systemic Lupus Erythematosus
# 	Hydroxychloroquine use predicts complete renal remission within 12 months among patients treated with mycophenolate mofetil therapy for membranous lupus nephritis
# Accumulated reranking cost: 0.40446525
# --------------------------------------------------------------------------------
# Run: 14 --- Title: Enantiomeric quality control of <i>R</i>‐Tofisopam by HPLC using polysaccharide‐type chiral stationary phases in polar organic mode, id: https://openalex.org/W2811785320
# Model: text-embedding-3-large, Tokens: 420, Cost: $0.00, Accumulated cost: $1.19
# Top 3 topics: ['Chiral Separation in Chromatography', 'Chiroptical Spectroscopy in Organic Compound Analysis', 'Atroposelective Synthesis of Axially Chiral Compounds']
# Model: text-embedding-3-large, Tokens: 558823, Cost: $0.07, Accumulated cost: $1.26
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 23 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 420, Cost: $0.00, Accumulated cost: $1.26
# Top 5 results:
# 	Management of validation of HPLC method for determination of acetylsalicylic acid impurities in a new pharmaceutical product
# 	Polysaccharide-based chiral stationary phases for high-performance liquid chromatographic enantioseparation
# 	Recent developments on polysaccharide-based chiral stationary phases for liquid-phase separation of enantiomers
# 	Recent trends in preparation, investigation and application of polysaccharide-based chiral stationary phases for separation of enantiomers in high-performance liquid chromatography
# 	Recent Advances in Separation and Analysis of Chiral Compounds
# Reranking...
# Total compare: 122, Total prompt tokens: 167615, Total completion tokens: 366
# Reranking cost: 0.02536185
# Reranked results:
# 	Method validation and determination of enantiomers and conformers in tofisopam drug substances and drug products by chiral high-performance liquid chromatography and kinetic and thermodynamic study of the interconversion of the conformers
# 	SEPARATION AND IDENTIFICATION OF TOFISOPAM STEREOISOMERS BY HYPHENATED HPLC-CD TECHNIQUE
# 	Recent developments in the high-throughput separation of biologically active chiral compounds via high performance liquid chromatography
# 	Polysaccharide-based chiral stationary phases for high-performance liquid chromatographic enantioseparation
# 	Recent trends in preparation, investigation and application of polysaccharide-based chiral stationary phases for separation of enantiomers in high-performance liquid chromatography
# Accumulated reranking cost: 0.4298271
# --------------------------------------------------------------------------------
# Run: 15 --- Title: Synthesis of multi‐unit protein hetero‐complexes in the gas phase via ion–ion chemistry, id: https://openalex.org/W1977094198
# Model: text-embedding-3-large, Tokens: 356, Cost: $0.00, Accumulated cost: $1.26
# Top 3 topics: ['Mass Spectrometry Techniques', 'Mass Spectrometry Techniques with Proteins', 'Peptide Synthesis and Drug Discovery']
# Model: text-embedding-3-large, Tokens: 639631, Cost: $0.08, Accumulated cost: $1.35
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 48 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 356, Cost: $0.00, Accumulated cost: $1.35
# Top 5 results:
# 	Electrospray Ionization for Mass Spectrometry of Large Biomolecules
# 	Molecular Beams of Macroions
# 	Electrospray Mass Spectrometry of Biomacromolecular Complexes with Noncovalent Interactions—New Analytical Perspectives for Supramolecular Chemistry and Molecular Recognition Processes
# 	Observation of noncovalent enzyme-substrate and enzyme-product complexes by ion-spray mass spectrometry
# 	Chemical Approaches to the Synthesis of Peptides and Proteins
# Reranking...
# Total compare: 142, Total prompt tokens: 205298, Total completion tokens: 426
# Reranking cost: 0.0310503
# Reranked results:
# 	Ion/ion chemistry of high-mass multiply charged ions
# 	A Quadrupole Ion Trap Mass Spectrometer with Three Independent Ion Sources for the Study of Gas-Phase Ion/Ion Reactions
# 	Native mass spectrometry—A valuable tool in structural biology
# 	Proton transfer reactions of multiply charged peptide and protein cations and anions
# 	Ion/Ion Reactions in the Gas Phase: Proton Transfer Reactions Involving Multiply-Charged Proteins
# Accumulated reranking cost: 0.4608774
# --------------------------------------------------------------------------------
# Run: 16 --- Title: Strengthening Children’s Advertising Defenses: The Effects of Forewarning of Commercial and Manipulative Intent, id: https://openalex.org/W2515944912
# Model: text-embedding-3-large, Tokens: 171, Cost: $0.00, Accumulated cost: $1.35
# Top 3 topics: ['Psychological and Marketing Implications of Nostalgia', 'Guidelines for Warning Design and Comprehension', 'Impact of Trigger Warnings in Education']
# Model: text-embedding-3-large, Tokens: 514686, Cost: $0.07, Accumulated cost: $1.41
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 56 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 171, Cost: $0.00, Accumulated cost: $1.41
# Top 5 results:
# 	Attitude toward the AD as a Mediator of Consumer Brand Choice
# 	Effect of television advertisements for foods on food consumption in children
# 	When Attention‐Getting Advertising Tactics Elicit Consumer Inferences of Manipulative Intent: The Importance of Balancing Benefits and Investments
# 	Children as Consumers: Advertising and Marketing
# 	Does Advertising Literacy Mediate the Effects of Advertising on Children? A Critical Examination of Two Linked Research Literatures in Relation to Obesity and Food Choice
# Reranking...
# Unexpected output: None of the passages are directly relevant to the query.
# Unexpected output: None
# Total compare: 131, Total prompt tokens: 117664, Total completion tokens: 399
# Reranking cost: 0.017889
# Reranked results:
# 	Reducing Children's Susceptibility to Commercials: Mechanisms of Factual and Evaluative Advertising Interventions
# 	Reconsidering Advertising Literacy as a Defense Against Advertising Effects
# 	Development and Validation of a Survey Instrument to Measure Children's Advertising Literacy
# 	Dispelling the illusion of invulnerability: The motivations and mechanisms of resistance to persuasion.
# 	Think-Aloud Process Superior to Thought-Listing in Increasing Children's Critical Processing of Advertising
# Accumulated reranking cost: 0.4787664
# --------------------------------------------------------------------------------
# Run: 17 --- Title: Zooplankton functional traits as a tool to assess latitudinal variation in the northern-southern temperate European regions during spring and autumn seasons, id: https://openalex.org/W3036393942
# Model: text-embedding-3-large, Tokens: 558, Cost: $0.00, Accumulated cost: $1.41
# Top 3 topics: ['Length-Weight Relationships of Fish Species', 'Influence of Land Use on Stream Ecosystems', 'Ecological Dynamics of African Great Lakes']
# Model: text-embedding-3-large, Tokens: 589007, Cost: $0.08, Accumulated cost: $1.49
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 40 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 558, Cost: $0.00, Accumulated cost: $1.49
# Top 5 results:
# 	Artifacts or Attributes? Effects of Resolution on the Little Rock Lake Food Web
# 	Trait-based approaches to zooplankton communities
# 	Plankton dynamics under different climatic conditions in space and time
# 	Mesopelagic Community off the North Western Portuguese Coast between 1998 and 2000
# 	Major restructuring of marine plankton assemblages under global warming
# Reranking...
# Total compare: 143, Total prompt tokens: 238925, Total completion tokens: 429
# Reranking cost: 0.036096149999999994
# Reranked results:
# 	Contrasting Zooplankton Assemblages in Two Oxbow Lakes with Low Transparencies and Narrow Emergent Macrophyte Belts (Krapina River, Croatia)
# 	Trait-based approaches to zooplankton communities
# 	Planktonic rotifers in mining lakes in the Silesian Upland: Relationship to environmental parameters
# 	Environmental Variables of Small Mid-Field Water Bodies and the Presence of Rotifera Groups of Different Ecological Requirements
# 	Zooplankton communities in doline lakes and pools, in relation to some bathymetric parameters and physical and chemical variables
# Accumulated reranking cost: 0.5148625499999999
# --------------------------------------------------------------------------------
# Run: 18 --- Title: Protective effect of stromal Dickkopf-3 in prostate cancer: opposing roles for TGFBI and ECM-1, id: https://openalex.org/W2805200921
# Model: text-embedding-3-large, Tokens: 360, Cost: $0.00, Accumulated cost: $1.49
# Top 3 topics: ['Transforming Growth Factor Beta Signaling Pathway', 'Role of CCN Proteins in Signaling Pathways', 'Role of Fibroblast Activation in Cancer Progression']
# Model: text-embedding-3-large, Tokens: 669890, Cost: $0.09, Accumulated cost: $1.58
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 49 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 360, Cost: $0.00, Accumulated cost: $1.58
# Top 5 results:
# 	TGFβ biology in cancer progression and immunotherapy
# 	Functional and structural diversity of the human Dickkopf gene family
# 	Fibrosis and cancer: A strained relationship
# 	Targeting TGF-β signal transduction for fibrosis and cancer therapy
# 	The reactive stroma microenvironment and prostate cancer progression
# Reranking...
# Total compare: 141, Total prompt tokens: 191051, Total completion tokens: 423
# Reranking cost: 0.028911449999999998
# Reranked results:
# 	Downregulation of Dickkopf-3 disrupts prostate acinar morphogenesis through TGF-β/Smad signaling
# 	Dickkopf-3 regulates prostate epithelial cell acinar morphogenesis and prostate cancer cell invasion by limiting TGF-β-dependent activation of matrix metalloproteases
# 	Dickkopf-3 function in the prostate
# 	Dysregulation of Dkk‐3 expression in benign and malignant prostatic tissue
# 	Dickkopf‐related protein 3 promotes pathogenic stromal remodeling in benign prostatic hyperplasia and prostate cancer
# Accumulated reranking cost: 0.5437739999999999
# --------------------------------------------------------------------------------
# Run: 19 --- Title: Business Cycles and Macroeconomic Policy in Emerging Market Economies, id: https://openalex.org/W2126300721
# Model: text-embedding-3-large, Tokens: 71, Cost: $0.00, Accumulated cost: $1.58
# Top 3 topics: ['Economic Development and Policy Analysis in Emerging Markets', 'Causes and Implications of Macroeconomic Trends', 'Macroeconomic Analysis and Policy Implications']
# Model: text-embedding-3-large, Tokens: 383951, Cost: $0.05, Accumulated cost: $1.63
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 38 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 71, Cost: $0.00, Accumulated cost: $1.63
# Top 5 results:
# 	Fear of Floating
# 	The Voracity Effect
# 	Fiscal Policy in Latin America
# 	The cyclical behaviour of fiscal policy: evidence from the OECD
# 	Currency crises and monetary policy in an economy with credit constraints
# Reranking...
# Total compare: 139, Total prompt tokens: 102716, Total completion tokens: 417
# Reranking cost: 0.0156576
# Reranked results:
# 	The cyclical behaviour of fiscal policy: A meta-analysis
# 	Tax Base Variability and Procyclical Fiscal Policy
# 	Fiscal Policy in Latin America
# 	Quantitative easing in the US and financial cycles in emerging markets
# 	Can Fiscal Rules Help Reduce Macroeconomic Volatility in the Latin America and Caribbean Region?
# Accumulated reranking cost: 0.5594315999999999
# --------------------------------------------------------------------------------
# Run: 20 --- Title: Classification of molecular structure images by using ANN, RF, LBP, HOG, and size reduction methods for early stomach cancer detection, id: https://openalex.org/W2770331144
# Model: text-embedding-3-large, Tokens: 259, Cost: $0.00, Accumulated cost: $1.63
# Top 3 topics: ['Gastric Cancer Research and Treatment', 'Deep Learning in Medical Image Analysis', 'Automated Analysis of Blood Cell Images']
# Model: text-embedding-3-large, Tokens: 758859, Cost: $0.10, Accumulated cost: $1.73
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 21 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 259, Cost: $0.00, Accumulated cost: $1.73
# Top 5 results:
# 	Visualizing Data using t-SNE
# 	Deep-learning framework to detect lung abnormality – A study with chest X-Ray and lung CT scan images
# 	Deep Learning Models for Histopathological Classification of Gastric and Colonic Epithelial Tumours
# 	Weakly Supervised Deep Learning for Whole Slide Lung Cancer Image Analysis
# 	Automated invasive ductal carcinoma detection based using deep transfer learning with whole-slide images
# Reranking...
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Total compare: 117, Total prompt tokens: 150521, Total completion tokens: 317
# Reranking cost: 0.02276835
# Reranked results:
# 	Clinically applicable histopathological diagnosis system for gastric cancer detection using deep learning
# 	Using RNN Artificial Neural Network to Predict the Occurrence of Gastric Cancer in the Future of the World
# 	Detecting early gastric cancer: Comparison between the diagnostic ability of convolutional neural networks and endoscopists
# 	Development and validation of a CT-based radiomic nomogram for preoperative prediction of early recurrence in advanced gastric cancer
# 	Deep Learning Models for Histopathological Classification of Gastric and Colonic Epithelial Tumours
# Accumulated reranking cost: 0.5821999499999999
# --------------------------------------------------------------------------------
# Run: 21 --- Title: Using Inquiry Empowering Technologies to Support Prospective Teachers’ Scientific Inquiry and Science Learning, id: https://openalex.org/W1560354504
# Model: text-embedding-3-large, Tokens: 164, Cost: $0.00, Accumulated cost: $1.73
# Top 3 topics: ['Enhancing Science Education through Inquiry and Argumentation', 'Impact of Education Technology on Learning Outcomes', 'Innovations in Education Technology and Pedagogy']
# Model: text-embedding-3-large, Tokens: 463934, Cost: $0.06, Accumulated cost: $1.79
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 18 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 164, Cost: $0.00, Accumulated cost: $1.79
# Top 5 results:
# 	Learning-for-use: A framework for the design of technology-supported inquiry activities
# 	Variability of teachers’ technology integration in the classroom: A matter of utility!
# 	Exploration of learner-content interactions and learning approaches: The role of guided inquiry in the self-directed online environments
# 	University students’ approaches to online learning technologies: The roles of perceived support, affect/emotion and self-efficacy in technology-enhanced learning
# 	Harnessing technology integration in education: Strategies for enhancing learning outcomes and equity
# Reranking...
# Total compare: 136, Total prompt tokens: 135045, Total completion tokens: 408
# Reranking cost: 0.02050155
# Reranked results:
# 	Inquiry-based science education in science teacher education: a systematic review
# 	Measurement of student attitudes to science and association with inquiry-based learning in regional schools
# 	Evolving explanations in high school biology
# 	Learning-for-use: A framework for the design of technology-supported inquiry activities
# 	Using a Web-Based Task To Make Prospective Elementary Teachers' Personal Theorizing about Science Teaching Explicit
# Accumulated reranking cost: 0.6027014999999999
# --------------------------------------------------------------------------------
# Run: 22 --- Title: Cadence and the empirical modelling conceptual framework : a new perspective on modelling state-as-experienced, id: https://openalex.org/W2103267246
# Model: text-embedding-3-large, Tokens: 392, Cost: $0.00, Accumulated cost: $1.79
# Top 3 topics: ['Model-Driven Engineering in Software Development', 'The Cognitive Revolution: Interdisciplinary Perspectives on Mind and Society', 'Dialogue Act Modeling for Spoken Language Systems']
# Model: text-embedding-3-large, Tokens: 420683, Cost: $0.05, Accumulated cost: $1.84
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 18 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 392, Cost: $0.00, Accumulated cost: $1.84
# Top 5 results:
# 	Adaptability of model transformations
# 	Role play with large language models
# 	Deltaware: Incremental Change Propagation for Automating Software Evolution in Model-Driven Architecture
# 	Music composition and the computer : an examination of the work practices of five experienced composers
# 	Towards a Notion of Agent Coordination Context
# Reranking...
# Total compare: 141, Total prompt tokens: 184539, Total completion tokens: 423
# Reranking cost: 0.02793465
# Reranked results:
# 	Modelling with Experience: Construal and Construction for Software
# 	Supporting the migration from construal to program : rethinking software development
# 	Empirical Modelling and the Foundations of Artificial Intelligence
# 	Empirical Modelling as an unconventional approach to software development
# 	Radical Empiricism, Empirical Modelling and the nature of knowing
# Accumulated reranking cost: 0.6306361499999998
# --------------------------------------------------------------------------------
# Run: 23 --- Title: About:Kate – Bildungsprozesse crossmedialer Serialität, id: https://openalex.org/W2735062223
# Model: text-embedding-3-large, Tokens: 206, Cost: $0.00, Accumulated cost: $1.84
# Top 3 topics: ['Understanding Social Television Viewing and Interaction', 'Theory of Social Practices in Education and Society', 'Interdisciplinary Study of Theatrical Performance and Theory']
# Model: text-embedding-3-large, Tokens: 472315, Cost: $0.06, Accumulated cost: $1.90
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 23 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 206, Cost: $0.00, Accumulated cost: $1.90
# Top 5 results:
# 	Narrative Complexity in Contemporary American Television
# 	Chor und Theorie
# 	Handeln im Kontext der Medien- und informatischen Bildung
# 	From Beats to Arcs: Toward a Poetics of Television Narrative
# 	Bühnen der Altermundialität. Vom Bild der Welt zur räumlichen Theaterpraxis
# Reranking...
# Total compare: 126, Total prompt tokens: 127370, Total completion tokens: 378
# Reranking cost: 0.019332299999999997
# Reranked results:
# 	The machine without the ghost: Early interactive television in Japan
# 	Cultural Studies And Critical Pedagogy
# 	Narrative Complexity in Contemporary American Television
# 	Digital Seriality as Structure and Process
# 	Perspektiven der Cyber-Society Plädoyer für eine kritische und kontextuelle Analyse digitaler Praktiken
# Accumulated reranking cost: 0.6499684499999998
# --------------------------------------------------------------------------------
# Run: 24 --- Title: The electrostatic spray emitted from an electrified conical meniscus, id: https://openalex.org/W2143284193
# Model: text-embedding-3-large, Tokens: 154, Cost: $0.00, Accumulated cost: $1.90
# Top 3 topics: ['Electrohydrodynamic Jet Printing and Nanoparticle Encapsulation', 'Turbulent Interactions with Dispersed Particles and Droplets', 'Dynamics of Drop Impact on Surfaces']
# Model: text-embedding-3-large, Tokens: 527589, Cost: $0.07, Accumulated cost: $1.97
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# ...
# Accumulated reranking cost: 2.5504113000000004
# --------------------------------------------------------------------------------
# Run: 93 --- Title: Nitrogen as a threat to European terrestrial biodiversity, id: https://openalex.org/W2208747462
# Model: text-embedding-3-large, Tokens: 50, Cost: $0.00, Accumulated cost: $7.48
# Top 3 topics: ['Biodiversity Conservation and Ecosystem Management', 'Marine Biodiversity and Ecosystem Functioning', 'Diversity and Evolution of Bryophytes']
# Model: text-embedding-3-large, Tokens: 562515, Cost: $0.07, Accumulated cost: $7.55
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 102 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 50, Cost: $0.00, Accumulated cost: $7.55
# Top 5 results:
# 	Global Biodiversity Scenarios for the Year 2100
# 	Scientists’ warning to humanity on the freshwater biodiversity crisis
# 	The Convention on Biological Diversity's 2010 Target
# 	Ecological variables for developing a global deep-ocean monitoring and conservation strategy
# 	The number of tree species on Earth
# Reranking...
# Total compare: 131, Total prompt tokens: 119884, Total completion tokens: 393
# Reranking cost: 0.0182184
# Reranked results:
# 	People need freshwater biodiversity
# 	The essential role of biodiversity in the key axes of ecosystem function
# 	Maximum levels of global phylogenetic diversity efficiently capture plant services for humankind
# 	Reconsidering functional redundancy in biodiversity research
# 	Critical review of methods and models for biodiversity impact assessment and their applicability in the LCA context
# Accumulated reranking cost: 2.5686297000000002
# --------------------------------------------------------------------------------
# Run: 94 --- Title: Ultrasonic studies on colossal magnetoresistive La1−xCaxMnO3 (x=0.25, 0.33 and 0.45), id: https://openalex.org/W2061068212
# Model: text-embedding-3-large, Tokens: 131, Cost: $0.00, Accumulated cost: $7.55
# Top 3 topics: ['Magnetocaloric Materials Research', 'Giant Dielectric Constant Materials and Phenomena', 'Magnetostriction in Magnetic Materials']
# Model: text-embedding-3-large, Tokens: 524179, Cost: $0.07, Accumulated cost: $7.62
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 19 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 131, Cost: $0.00, Accumulated cost: $7.62
# Top 5 results:
# 	Double Exchange Alone Does Not Explain the Resistivity of<mml:math xmlns:mml="http://www.w3.org/1998/Math/MathML" display="inline"><mml:mrow><mml:msub><mml:mrow><mml:mrow><mml:msub><mml:mrow><mml:mi>La</mml:mi></mml:mrow><mml:mrow><mml:mn>1</mml:mn></mml:mrow></mml:msub></mml:mrow></mml:mrow><mml:mrow><mml:mo>−</mml:mo><mml:mi mathvariant="italic">x</mml:mi></mml:mrow></mml:msub></mml:mrow><mml:mrow><mml:msub><mml:mrow><mml:mi>Sr</mml:mi></mml:mrow><mml:mrow><mml:mi mathvariant="italic">x</mml:…
# 	Low Temperature Magnetoresistance and the Magnetic Phase Diagram of<mml:math xmlns:mml="http://www.w3.org/1998/Math/MathML" display="inline"><mml:mrow><mml:msub><mml:mrow><mml:mi>La</mml:mi></mml:mrow><mml:mrow><mml:mn>1</mml:mn><mml:mo>−</mml:mo><mml:mi mathvariant="italic">x</mml:mi></mml:mrow></mml:msub></mml:mrow><mml:mrow><mml:msub><mml:mrow><mml:mi>Ca</mml:mi></mml:mrow><mml:mrow><mml:mi mathvariant="italic">x</mml:mi></mml:mrow></mml:msub></mml:mrow><mml:mrow><mml:msub><mml:mrow><mml:mi>…
# 	Dynamic Jahn-Teller Effect and Colossal Magnetoresistance in<mml:math xmlns:mml="http://www.w3.org/1998/Math/MathML" display="inline"><mml:mrow><mml:msub><mml:mrow><mml:mi>La</mml:mi></mml:mrow><mml:mrow><mml:mn>1</mml:mn><mml:mo>−</mml:mo><mml:mi mathvariant="italic">x</mml:mi></mml:mrow></mml:msub></mml:mrow><mml:mrow><mml:msub><mml:mrow><mml:mi>Sr</mml:mi></mml:mrow><mml:mrow><mml:mi mathvariant="italic">x</mml:mi></mml:mrow></mml:msub></mml:mrow><mml:mrow><mml:msub><mml:mrow><mml:mi>MnO</…
# 	Charge, orbital, and magnetic ordering in<mml:math xmlns:mml="http://www.w3.org/1998/Math/MathML" display="inline"><mml:mrow><mml:msub><mml:mrow><mml:mi mathvariant="normal">La</mml:mi></mml:mrow><mml:mrow><mml:mn>0.5</mml:mn></mml:mrow></mml:msub></mml:mrow></mml:math><mml:math xmlns:mml="http://www.w3.org/1998/Math/MathML" display="inline"><mml:mrow><mml:msub><mml:mrow><mml:mi mathvariant="normal">Ca</mml:mi></mml:mrow><mml:mrow><mml:mn>0.5</mml:mn></mml:mrow></mml:msub></mml:mrow></mml:math…
# 	Lattice Effects in the Colossal-Magnetoresistance Manganites
# Reranking...
# Total compare: 127, Total prompt tokens: 129808, Total completion tokens: 381
# Reranking cost: 0.019699799999999996
# Reranked results:
# 	Thermodynamic and Electron Diffraction Signatures of Charge and Spin Ordering in<mml:math xmlns:mml="http://www.w3.org/1998/Math/MathML" display="inline"><mml:mrow><mml:msub><mml:mrow><mml:mi>La</mml:mi></mml:mrow><mml:mrow><mml:mn>1</mml:mn><mml:mo>−</mml:mo><mml:mi mathvariant="italic">x</mml:mi></mml:mrow></mml:msub></mml:mrow><mml:mrow><mml:msub><mml:mrow><mml:mi>Ca</mml:mi></mml:mrow><mml:mrow><mml:mi mathvariant="italic">x</mml:mi></mml:mrow></mml:msub></mml:mrow><mml:mrow><mml:msub><mml:…
# 	Polaron transport and lattice dynamics in colossal-magnetoresistance manganites
# 	Effects of phonon hardening on the polaron transport in colossal magnetoresistive manganites
# 	Simultaneous Structural, Magnetic, and Electronic Transitions in<mml:math xmlns:mml="http://www.w3.org/1998/Math/MathML" display="inline"><mml:mrow><mml:msub><mml:mrow><mml:mi mathvariant="normal">La</mml:mi></mml:mrow><mml:mrow><mml:mn>1</mml:mn><mml:mo>−</mml:mo><mml:mi>x</mml:mi></mml:mrow></mml:msub></mml:mrow><mml:mrow><mml:msub><mml:mrow><mml:mi mathvariant="normal">Ca</mml:mi></mml:mrow><mml:mrow><mml:mi>x</mml:mi></mml:mrow></mml:msub></mml:mrow><mml:mi mathvariant="normal">Mn</mml:mi><…
# 	Phonon effects in colossal magnetoresistance manganese oxides
# Accumulated reranking cost: 2.5883295000000004
# --------------------------------------------------------------------------------
# Run: 95 --- Title: Rotavirus RNA chaperone mediates global transcriptome-wide increase in RNA backbone flexibility, id: https://openalex.org/W4206156586
# Model: text-embedding-3-large, Tokens: 281, Cost: $0.00, Accumulated cost: $7.62
# Top 3 topics: ['Regulation of RNA Processing and Function', 'Viral RNA Silencing and Plant Immunity', 'Gastrointestinal Viral Infections and Vaccines Development']
# Model: text-embedding-3-large, Tokens: 713030, Cost: $0.09, Accumulated cost: $7.71
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 45 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 281, Cost: $0.00, Accumulated cost: $7.71
# Top 5 results:
# 	The Architecture of SARS-CoV-2 Transcriptome
# 	RNAstructure: software for RNA secondary structure prediction and analysis
# 	Architecture and secondary structure of an entire HIV-1 RNA genome
# 	RNA Structure Analysis at Single Nucleotide Resolution by Selective 2‘-Hydroxyl Acylation and Primer Extension (SHAPE)
# 	Accurate SHAPE-directed RNA structure determination
# Reranking...
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Unexpected output: None
# Total compare: 144, Total prompt tokens: 199443, Total completion tokens: 473
# Reranking cost: 0.030200249999999998
# Reranked results:
# 	Protein-mediated RNA folding governs sequence-specific interactions between rotavirus genome segments
# 	Stability of local secondary structure determines selectivity of viral RNA chaperones
# 	RNA motif discovery by SHAPE and mutational profiling (SHAPE-MaP)
# 	Assortment and packaging of the segmented rotavirus genome
# 	Principles of RNA recruitment to viral ribonucleoprotein condensates in a segmented dsRNA virus
# Accumulated reranking cost: 2.6185297500000004
# --------------------------------------------------------------------------------
# Run: 96 --- Title: Eocene through Quaternary Planktonic Foraminifers from the Northwest Pacific, Leg 126, id: https://openalex.org/W2186940396
# Model: text-embedding-3-large, Tokens: 330, Cost: $0.00, Accumulated cost: $7.71
# Top 3 topics: ['Paleoredox and Paleoproductivity Proxies', 'Paleoceanography and Geology of the Black Sea', "Sedimentary Processes in Earth's Geology"]
# Model: text-embedding-3-large, Tokens: 621303, Cost: $0.08, Accumulated cost: $7.79
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 12 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 330, Cost: $0.00, Accumulated cost: $7.79
# Top 5 results:
# 	Cenozoic geochronology
# 	Cenozoic sea-level and cryospheric evolution from deep-sea geochemical and continental margin records
# 	Paleoceanographic implications of Miocene deep-sea hiatuses
# 	Planktonic Foraminifera: selective solution and paleoclimatic interpretation
# 	Deep-sea carbonates; Pleistocene dissolution cycles
# Reranking...
# Total compare: 132, Total prompt tokens: 192825, Total completion tokens: 449
# Reranking cost: 0.029193149999999998
# Reranked results:
# 	Planktonic Foraminifera: selective solution and paleoclimatic interpretation
# 	Ranking of dissolution susceptibility of planktonic foraminifera at high latitudes of the South Atlantic Ocean
# 	Revisiting the Middle Eocene Climatic Optimum “Carbon Cycle Conundrum” With New Estimates of Atmospheric pCO<sub>2</sub> From Boron Isotopes
# 	Faunal and solution patterns of planktonic foraminifera in surface sediments of the North Pacific
# 	Ecological Response of Plankton to Environmental Change: Thresholds for Extinction
# Accumulated reranking cost: 2.6477229
# --------------------------------------------------------------------------------
# Run: 97 --- Title: Non-Religious Identity Salience for Candidate Choice, id: https://openalex.org/W4391187379
# Model: text-embedding-3-large, Tokens: 160, Cost: $0.00, Accumulated cost: $7.79
# Top 3 topics: ['Religion and Secularism in Modern Society', 'Religion and Politics in Brazil and Latin America', 'Influence of Religion on Environmental Concern and Activism']
# Model: text-embedding-3-large, Tokens: 465623, Cost: $0.06, Accumulated cost: $7.85
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 25 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 160, Cost: $0.00, Accumulated cost: $7.85
# Top 5 results:
# 	Atheists As “Other”: Moral Boundaries and Cultural Membership in American Society
# 	Do you believe in atheists? Distrust is central to anti-atheist prejudice.
# 	Christian Nationalism and Political Violence: Victimhood, Racial Identity, Conspiracy, and Support for the Capitol Attacks
# 	Creating a Godless Community: The Collective Identity Work of Contemporary American Atheists
# 	White Christian Nationalism and Relative Political Tolerance for Racists
# Reranking...
# Total compare: 134, Total prompt tokens: 121910, Total completion tokens: 459
# Reranking cost: 0.0185619
# Reranked results:
# 	Atheists As “Other”: Moral Boundaries and Cultural Membership in American Society
# 	Do you believe in atheists? Distrust is central to anti-atheist prejudice.
# 	The Relevance of Religion for Political Office: Voter Bias Toward Candidates from Different Religious Backgrounds
# 	Nonverts
# 	The Politics of Religious Nones
# Accumulated reranking cost: 2.6662848
# --------------------------------------------------------------------------------
# Run: 98 --- Title: Mechanisms of Fetal T Cell Tolerance and Immune Regulation, id: https://openalex.org/W3015830199
# Model: text-embedding-3-large, Tokens: 300, Cost: $0.00, Accumulated cost: $7.85
# Top 3 topics: ['Immunological Mechanisms in Pregnancy and Fetal-Maternal Interface', 'Regulatory T Cell Development and Function', 'Trained Immunity in Health and Disease']
# Model: text-embedding-3-large, Tokens: 705235, Cost: $0.09, Accumulated cost: $7.95
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 150 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 300, Cost: $0.00, Accumulated cost: $7.95
# Top 5 results:
# 	Immunology of the Maternal-Fetal Interface
# 	Maternal Alloantigens Promote the Development of Tolerogenic Fetal Regulatory T Cells in Utero
# 	Transplacental Priming of the Human Immune System to Environmental Allergens: Universal Skewing of Initial T Cell Responses Toward the Th2 Cytokine Profile
# 	Induction of T <sub>H</sub> 1 and T <sub>H</sub> 2 Immunity in Neonatal Mice
# 	Stereotypic Immune System Development in Newborn Children
# Reranking...
# Total compare: 137, Total prompt tokens: 165051, Total completion tokens: 411
# Reranking cost: 0.02500425
# Reranked results:
# 	CD161 mediates prenatal immune suppression of IFNγ-producing PLZF<sup>+</sup>T cells
# 	Maternal Alloantigens Promote the Development of Tolerogenic Fetal Regulatory T Cells in Utero
# 	T Helper (Th) Cell Profiles in Pregnancy and Recurrent Pregnancy Losses: Th1/Th2/Th9/Th17/Th22/Tfh Cells
# 	Fetal and Adult Hematopoietic Stem Cells Give Rise to Distinct T Cell Lineages in Humans
# 	Human fetal dendritic cells promote prenatal T-cell immune suppression through arginase-2
# Accumulated reranking cost: 2.69128905
# --------------------------------------------------------------------------------
# Run: 99 --- Title: Infections in haematology patients treated with CAR-T therapies: A systematic review and meta-analysis, id: https://openalex.org/W4386898729
# Model: text-embedding-3-large, Tokens: 252, Cost: $0.00, Accumulated cost: $7.95
# Top 3 topics: ['Chimeric Antigen Receptor T Cell Therapy', 'Management of Febrile Neutropenia in Cancer Patients', 'Viral-Related Cancers in Immunocompromised Patients']
# Model: text-embedding-3-large, Tokens: 728532, Cost: $0.09, Accumulated cost: $8.04
# Retrieved and inserted 2000 publications.
# Rebuilding BM25 index...
# Rebuilt BM25 index.
# Inserted 62 referenced works.
# Found all referenced works in the database? True
# Model: text-embedding-3-large, Tokens: 252, Cost: $0.00, Accumulated cost: $8.04
# Top 5 results:
# 	Ciltacabtagene autoleucel, a B-cell maturation antigen-directed chimeric antigen receptor T-cell therapy in patients with relapsed or refractory multiple myeloma (CARTITUDE-1): a phase 1b/2 open-label study
# 	KTE-X19 for relapsed or refractory adult B-cell acute lymphoblastic leukaemia: phase 2 results of the single-arm, open-label, multicentre ZUMA-3 study
# 	Real-world evidence of tisagenlecleucel for pediatric acute lymphoblastic leukemia and non-Hodgkin lymphoma
# 	Long-term clinical outcomes of tisagenlecleucel in patients with relapsed or refractory aggressive B-cell lymphomas (JULIET): a multicentre, open-label, single-arm, phase 2 study
# 	Late Events after Treatment with CD19-Targeted Chimeric Antigen Receptor Modified T Cells
# Reranking...
# Total compare: 138, Total prompt tokens: 258198, Total completion tokens: 414
# Reranking cost: 0.0389781
# Reranked results:
# 	Infectious Complications in Aggressive B Cell Non-Hodgkin Lymphoma after CD-19 Chimeric Antigen Receptor T Cell Therapy
# 	Cytokine Release Syndrome Grade as a Predictive Marker for Infections in Patients With Relapsed or Refractory B-Cell Acute Lymphoblastic Leukemia Treated With Chimeric Antigen Receptor T Cells
# 	Steroid Use, Advanced Stage Disease and ≥3 Lines of Prior Chemotherapy Are Associated with a Higher Risk of Infection Following CD19 CAR T-Cell Therapy for B-NHL: Real World Data from a Large UK Center
# 	Chimeric antigen receptor T-cell therapy for the treatment of lymphoid malignancies: is there an excess risk for infection?
# 	Infectious complications, immune reconstitution, and infection prophylaxis after CD19 chimeric antigen receptor T-cell therapy
# Accumulated reranking cost: 2.73026715
# --------------------------------------------------------------------------------
